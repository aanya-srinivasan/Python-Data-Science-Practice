# %%
import pandas as pd

# %%
pd.read_csv('example')
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
df = pd.read_csv('example')

# %%
df.to_csv('My Output', index = False) #write

# %%
pd.read_csv('My Output')
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
df2 = pd.read_excel('Excel_Sample.xlsx', sheet_name = 'Sheet1', index_col = 0)

# %%
df2.to_excel('Excel_Sample2.xlsx', sheet_name = 'NewSheet')

# %%
pd.read_excel('Excel_Sample2.xlsx', sheet_name = 'NewSheet')
# Out:
#    Unnamed: 0   a   b   c   d
# 0           0   0   1   2   3
# 1           1   4   5   6   7
# 2           2   8   9  10  11
# 3           3  12  13  14  15

# %%
df = pd.read_html('http://www.fdic.gov/bank/individual/failed/banklist.html')

# %%
df[0].head()
# Out:
#                                Bank Name           City         State   Cert  \
# 0     The First National Bank of Lindsay        Lindsay      Oklahoma   4134
# 1  Republic First Bank dba Republic Bank   Philadelphia  Pennsylvania  27332
# 2                          Citizens Bank       Sac City          Iowa   8758
# 3               Heartland Tri-State Bank        Elkhart        Kansas  25851
# 4                    First Republic Bank  San Francisco    California  59017
#
#                  Aquiring Institution      Closing Date  Fund  Sort ascending
# 0  First Bank & Trust Co., Duncan, OK  October 18, 2024                 10547
# 1   Fulton Bank, National Association    April 26, 2024                 10546
# 2           Iowa Trust & Savings Bank  November 3, 2023                 10545
# 3              Dream First Bank, N.A.     July 28, 2023                 10544
# 4           JPMorgan Chase Bank, N.A.       May 1, 2023                 10543

# %%
pd.read_csv('banklist.csv', encoding='ISO-8859-1')
# Out:
#                                 Bank Name           City  State   Cert   \
# 0           First National Bank of Lindsay        Lindsay     OK   4134
# 1    Republic First Bank dba Republic Bank   Philadelphia     PA  27332
# 2                            Citizens Bank       Sac City     IA   8758
# 3                 Heartland Tri-State Bank        Elkhart     KS  25851
# 4                      First Republic Bank  San Francisco     CA  59017
# ..                                     ...            ...    ...    ...
# 565                     Superior Bank, FSB       Hinsdale     IL  32646
# 566                    Malta National Bank          Malta     OH   6629
# 567        First Alliance Bank & Trust Co.     Manchester     NH  34264
# 568      National State Bank of Metropolis     Metropolis     IL   3815
# 569                       Bank of Honolulu       Honolulu     HI  21029
#
#                   Acquiring Institution  Closing Date    Fund
# ...

# %%
juv = pd.read_excel('MMC Juv.xlsx', sheet_name = 'Juvenile')

# %%
juv
# Out:
#          Date Label Female Size  # Red F  # Red M  # Brown F   # Brown M  \
# 0  2024-06-11    L1           L        7       15          62         58
# 1  2024-06-11   L10           L       10       16          66         71
# 2  2024-06-11    L2           L       14       12          65         62
# 3  2024-06-11    L3           L       15       10          49         50
# 4  2024-06-11    L4           L       14       10          73         69
# ..        ...   ...         ...      ...      ...         ...        ...
# 95 2024-09-17    S5           S       14       11          56         67
# 96 2024-09-17    S2           S       14       11          64         71
# 97 2024-09-17    S3           S        9       13          60         65
# 98 2024-09-17    S1           S       15       14          60         61
# 99 2024-09-17   S10           S       11       14          67         65
#
#     Total Red  Total Brown  Total Number of Flies  Red Juvenile Survival
# ...

# %%
juv.dropna()
# Out:
#          Date Label Female Size  # Red F  # Red M  # Brown F   # Brown M  \
# 0  2024-06-11    L1           L        7       15          62         58
# 1  2024-06-11   L10           L       10       16          66         71
# 2  2024-06-11    L2           L       14       12          65         62
# 3  2024-06-11    L3           L       15       10          49         50
# 4  2024-06-11    L4           L       14       10          73         69
# ..        ...   ...         ...      ...      ...         ...        ...
# 95 2024-09-17    S5           S       14       11          56         67
# 96 2024-09-17    S2           S       14       11          64         71
# 97 2024-09-17    S3           S        9       13          60         65
# 98 2024-09-17    S1           S       15       14          60         61
# 99 2024-09-17   S10           S       11       14          67         65
#
#     Total Red  Total Brown  Total Number of Flies  Red Juvenile Survival
# ...

# %%
juv.groupby('Female Size')['Red Juvenile Survival'].mean()
# Out:
# Female Size
# L    0.832
# S    0.878
# Name: Red Juvenile Survival, dtype: float64

# %%
juv['Female Size'].value_counts()
# Out:
# Female Size
# L    50
# S    50
# Name: count, dtype: int64

# %%
juv['Total Red'].value_counts()
# Out:
# Total Red
# 25    20
# 26    18
# 28    15
# 27    13
# 22     9
# 24     7
# 23     5
# 29     5
# 33     2
# 21     2
# 19     2
# 34     1
# 20     1
# Name: count, dtype: int64

# %%
juv['Total Number of Flies'].sum()
# Out:
# 15389
